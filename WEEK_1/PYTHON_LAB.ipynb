# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrasekhar77803/PYTHON--LAB/blob/main/WEEK_1/PYTHON_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##PROGRAM_1

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ##PROGRAM ON output function and knowing type:
# To know the data type of variable we have a function type().we dont have char in python here only we have str datatype.we use single or double quotes for character and string our wish.we can directly write expression.we use print function this is output function.syntax:print("").

# %%
a=2
print(type(a))
v=2.3
print(type(v))
str='chandu'
print(type(str))
print(2*6-8/12)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 11.333333333333334

# %% [markdown]
# ##p

# %% [markdown]
# ##PROGREAM ON input function(reading inputfrom user):
# in python inputfunction is syntax:input("").but inputfunction reads data only in string os we convert string into int or float our need.in inputfunction we also enter text to ask anything from user like input("enter some text or enter a value")

# %%
a=2
print(a)
# a=input()
# print(a)
#a value overwritten input only in string so convert it into int or float
a=int(input())
print(a)
print(type(a))
str=input("enter some text")
print(str)
# Out:
# 2
# 5
# 5
# <class 'int'>
# enter some texthello sir goodmorning
# hello sir goodmorning

# %% [markdown]
# ##PROGRAM ON ARTHIMATIC OPERATORS

# %%
a=int(input("enter a value"))
b=int(input("enter b value"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# enter a value15
# enter b value10
# 25
# 5
# 150
# 1.5
# 1
# 5
