# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrasekhar77803/PYTHON--LAB/blob/main/WEEK_2/PYTHON_LAB-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##FINDING GRATEST AMONG THREE

# %%
a=input("enter a value")
b=input("enter b value")
c=input("enter c value")
if(a>b and a>c):
  print(f"{a} is greater")
elif(b>c):
  print(f"{b} is greater")
else:
  print(f"{c} is greater")
# Out:
# enter a value10
# enter b value45
# enter c value78
# 78 is greater

# %% [markdown]
# #print FIZZ if a number is dividible by 3,print BUZZ if a num is divisible by 5 print FIZZBUZZ if it is diisible by both

# %%
n=int(input("enter a value"))
if(n%3==0 and n%5==0):
  print("FIZZBUZZ")
elif(n%3==0):
  print("FIZZ")
else:
  print("BUZZ")
# Out:
# enter a value15
# FIZZBUZZ

# %% [markdown]
# ##program on operations on complex numbers

# %%
'''
a=int(input())
b=int(input())
z=complex(a,b)
c=int(input())
d=int(input())
y=complex(c,d)
print(z+y)
print(z*y)
print(z-y)
print(z/y)
'''
z=complex(input("enter 1st complex number"))
y=complex(input("enter 1st complex number"))
print(z+y)
print(z*y)
print(z-y)
print(z/y)
# Out:
# enter 1st complex number2+3j
# enter 1st complex number2+3j
# (4+6j)
# (-5+12j)
# 0j
# (1+0j)

# %% [markdown]
# ##program that swaps 2 variables

# %%
a=int(input("enter a value"))
b=int(input("enter b value"))
print(a,b)
a,b=b,a
print(f"after swapping a={a},b={b}")
# Out:
# enter a value2
# enter b value3
# 2 3
# after swapping a=3,b=2

# %% [markdown]
# ##program on match case
#
# ---

# %%
day=int(input("enter any number"))
match day:
  case 1:
    print("monday")
  case 2:
    print("tuesday")
  case 3:
    print("wednesday")
  case 4:
    print("thursday")
  case 5:
    print("friday")
  case 6:
    print("saturday")
  case 7:
    print("sunday")
  case _:
    print("default")
# Out:
# enter any number0
# default

# %% [markdown]
# ##PROGRAMS ON LOOPS

# %%
i=1
while(i<=5):
  print("python",end=" ")
  i+=1
  if(i==3):
    break
#print("end")
else:
  print("loop ended")
# Out:
# python python

# %% [markdown]
# #program on printing one to 10 using while loop

# %%
#i=1
# while(i<=10):
#   print(f"{i}",end=" ")
#   i+=1
# i=10
# while(i>=1):
#   print(f"{i}",end=" ")
#   i-=1
i=1
# while(i<=10):
#   if(i%2==0):
#     print(f"{i}",end=" ")
#   i+=1
while(i<=10):
  if(i%2!=0):
    print(f"{i}",end=" ")
  i+=1
# Out:
# 1 3 5 7 9
